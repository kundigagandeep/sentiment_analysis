# %% [markdown]
# <a href="https://colab.research.google.com/github/kundigagandeep/sentiment_analysis/blob/main/Google_Play_Reviews_Sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google_play_scraper #Scraping reviews
# !pip install -q transformers #Sentiment
# !pip install -q plotly-express #Data Visualization

# %%
# !pip install pyyaml==5.4.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml==5.4.1 in /usr/local/lib/python3.7/dist-packages (5.4.1)

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, Sort, reviews_all
import plotly.express as px
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning:
#
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
hk_project = reviews_all( 'com.hikingproject.android', sleep_milliseconds=0, lang ='en',country='US', sort=Sort.NEWEST)

# %%
#hk_project

# %%
df = pd.json_normalize(hk_project)

# %%
df.head()
# Out:
#                                reviewId         userName  \
# 0  7a8088bd-4a3f-4a80-9868-08a0f7bbc287  Susan and Randy
# 1  87bf427a-3447-4c69-a2e4-963b559941f5     Scott Bishop
# 2  3406a592-efa3-49e5-a1d5-85674e47b452    Balakrishna S
# 3  3d6782e1-913c-459a-8825-4b71b18c865e  Charles W Phone
# 4  8e1d37e5-1f28-4cf0-bacf-3f43127e00c0    Tom Hirashima
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AATXAJ...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a/AATXAJ...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0  refuses to move data or app onto the sdcard. t...      1              1
# 1  There's no way to filter trails by length, ele...      1              0
# 2  Loved in Michigan, Love it in Massachusettes. ...      5              0
# 3      Can not export or save track in free version,      1              0
# 4  Great app. Lots of good information about the ...      4              1
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0              22.10.0 2022-06-11 19:27:41         None       NaT
# 1              22.10.0 2022-06-10 19:59:54         None       NaT
# 2              22.10.0 2022-06-10 15:29:32         None       NaT
# 3              22.10.0 2022-06-06 08:05:53         None       NaT
# 4              22.10.0 2022-06-05 16:24:19         None       NaT

# %%
df['score'].mean()
# Out:
# 3.817378497790869

# %%
df['reviewCreatedVersion'].value_counts()
# Out:
# 3.2.8      83
# 3.2.1      57
# 3.2.6      54
# 3.2.5      52
# 21.14.0    51
# 3.4.0      49
# 3.1.1      48
# 3.11.0     43
# 3.2.4      24
# 3.13.1     23
# 3.8.0      22
# 1.25       19
# 3.12.2     18
# 3.1.0      18
# 22.10.0    16
# 3.10.0     11
# 3.3.1       9
# 3.5.2       7
# 3.12.1      6
# 3.2.7       5
# 3.6.2       3
# 3.2.0       3
# 3.5.0       2
# 3.7.0       2
# 1.22        2
# 3.0.1       1
# 1.2         1
# 1.11        1
# Name: reviewCreatedVersion, dtype: int64

# %%
from transformers import pipeline

sentiment_analysis = pipeline("sentiment-analysis",model="siebert/sentiment-roberta-large-english")
# Out:
# Downloading:   0%|          | 0.00/687 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/256 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
print(sentiment_analysis("I love this!"))
# Out:
# [{'label': 'POSITIVE', 'score': 0.9988656044006348}]

# %%
df.dtypes
# Out:
# reviewId                        object
# userName                        object
# userImage                       object
# content                         object
# score                            int64
# thumbsUpCount                    int64
# reviewCreatedVersion            object
# at                      datetime64[ns]
# replyContent                    object
# repliedAt               datetime64[ns]
# dtype: object

# %%
df['content'] = df['content'].astype('str')

# %%
df['result'] = df['content'].apply(lambda x: sentiment_analysis(x))

# %%
df.head()
# Out:
#                                reviewId         userName  \
# 0  7a8088bd-4a3f-4a80-9868-08a0f7bbc287  Susan and Randy
# 1  87bf427a-3447-4c69-a2e4-963b559941f5     Scott Bishop
# 2  3406a592-efa3-49e5-a1d5-85674e47b452    Balakrishna S
# 3  3d6782e1-913c-459a-8825-4b71b18c865e  Charles W Phone
# 4  8e1d37e5-1f28-4cf0-bacf-3f43127e00c0    Tom Hirashima
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AATXAJ...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a/AATXAJ...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0  refuses to move data or app onto the sdcard. t...      1              1
# 1  There's no way to filter trails by length, ele...      1              0
# 2  Loved in Michigan, Love it in Massachusettes. ...      5              0
# 3      Can not export or save track in free version,      1              0
# 4  Great app. Lots of good information about the ...      4              1
#
#   reviewCreatedVersion                  at replyContent repliedAt  \
# 0              22.10.0 2022-06-11 19:27:41         None       NaT
# 1              22.10.0 2022-06-10 19:59:54         None       NaT
# 2              22.10.0 2022-06-10 15:29:32         None       NaT
# 3              22.10.0 2022-06-06 08:05:53         None       NaT
# 4              22.10.0 2022-06-05 16:24:19         None       NaT
#
#                                               result
# 0  [{'label': 'NEGATIVE', 'score': 0.999508261680...
# 1  [{'label': 'NEGATIVE', 'score': 0.999510765075...
# 2  [{'label': 'POSITIVE', 'score': 0.998806476593...
# 3  [{'label': 'NEGATIVE', 'score': 0.999426960945...
# 4  [{'label': 'POSITIVE', 'score': 0.998839557170...

# %%
y = sentiment_analysis("I love this!")

# %%
y[0]['label']
# Out:
# 'POSITIVE'

# %%
y[0]['score']
# Out:
# 0.9988656044006348

# %%
df['sentiment']= df['result'].apply(lambda x: (x[0]['label']))
df['score']= df['result'].apply(lambda x: (x[0]['score']))

# %%
df.head()
# Out:
#                                reviewId         userName  \
# 0  7a8088bd-4a3f-4a80-9868-08a0f7bbc287  Susan and Randy
# 1  87bf427a-3447-4c69-a2e4-963b559941f5     Scott Bishop
# 2  3406a592-efa3-49e5-a1d5-85674e47b452    Balakrishna S
# 3  3d6782e1-913c-459a-8825-4b71b18c865e  Charles W Phone
# 4  8e1d37e5-1f28-4cf0-bacf-3f43127e00c0    Tom Hirashima
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AATXAJ...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a/AATXAJ...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content     score  thumbsUpCount  \
# 0  refuses to move data or app onto the sdcard. t...  0.999508              1
# 1  There's no way to filter trails by length, ele...  0.999511              0
# 2  Loved in Michigan, Love it in Massachusettes. ...  0.998806              0
# 3      Can not export or save track in free version,  0.999427              0
# 4  Great app. Lots of good information about the ...  0.998840              1
#
#   reviewCreatedVersion                  at replyContent repliedAt  \
# 0              22.10.0 2022-06-11 19:27:41         None       NaT
# 1              22.10.0 2022-06-10 19:59:54         None       NaT
# 2              22.10.0 2022-06-10 15:29:32         None       NaT
# 3              22.10.0 2022-06-06 08:05:53         None       NaT
# 4              22.10.0 2022-06-05 16:24:19         None       NaT
#
#                                               result sentiment
# 0  [{'label': 'NEGATIVE', 'score': 0.999508261680...  NEGATIVE
# 1  [{'label': 'NEGATIVE', 'score': 0.999510765075...  NEGATIVE
# 2  [{'label': 'POSITIVE', 'score': 0.998806476593...  POSITIVE
# 3  [{'label': 'NEGATIVE', 'score': 0.999426960945...  NEGATIVE
# 4  [{'label': 'POSITIVE', 'score': 0.998839557170...  POSITIVE

# %%
df['score'].mean()
# Out:
# 0.9974225141514033

# %%
df['sentiment'].value_counts(normalize=True)
# Out:
# POSITIVE    0.683358
# NEGATIVE    0.316642
# Name: sentiment, dtype: float64

# %%
fig = px.histogram(df, x='sentiment', color='sentiment', text_auto=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f96261d3-c524-44bd-b29a-880f432b59b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f96261d3-c524-44bd-b29a-880f432b59b3")) {                    Plotly.newPlot(                        "f96261d3-c524-44bd-b29a-880f432b59b3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sentiment=%{x}<br>count=%{y}<extra></extra>","legendgroup":"NEGATIVE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"NEGATIVE","offsetgroup":"NEGATIVE","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE","NEGATIVE"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sentiment=%{x}<br>count=%{y}<extra></extra>","legendgroup":"POSITIVE","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"POSITIVE","offsetgroup":"POSITIVE","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","PO ...

# %%
df.to_csv('Drive/Gagan/sentiment.csv')
